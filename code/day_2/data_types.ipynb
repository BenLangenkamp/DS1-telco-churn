# %% [markdown]
# ### Primitive data types in Python

# %%
# 1. Integer

# Example: Age of a person
age = 25
print("Age:", age)
# Out:
# Age: 25

# %%
# 2. Float

# Example: Temperature in degrees Celsius
temperature = 23.5
print("Temperature:", temperature)
# Out:
# Temperature: 23.5

# %%
# 3. String

# Example: Name of a person
name = "Max Mustermann"
print("Name:", name)
# Out:
# Name: Max Mustermann

# %%
# 4. Boolean

# Example: Is the user logged in?
is_logged_in = True
print("Is logged in:", is_logged_in)
# Out:
# Is logged in: True

# %% [markdown]
# ### Applications of primitive data types:

# %%
# Integer: Performing calculations
x = 10
y = 5
sum_result = x + y
print("Sum:", sum_result)
# Out:
# Sum: 15

# %%
# Float: Calculating the average
grades = [1.0, 2.5, 3.7, 2.0, 1.3]
average_grade = sum(grades) / len(grades)
print("Average grade:", average_grade)
# Out:
# Average grade: 2.1

# %%
# String: Concatenating strings
first_name = "Max"
last_name = "Mustermann"
full_name = first_name + " " + last_name
print("Full name:", full_name)
# Out:
# Full name: Max Mustermann

# %%
# Boolean: Checking conditions
age = 20
is_adult = age >= 18
if is_adult:
    print("The user is an adult.")
else:
    print("The user is not an adult.")
# Out:
# The user is an adult.

# %% [markdown]
# ### Useful Python functions for primitive data types

# %%
# 1. type() function

# Example: Checking the data type of a variable
age = 25
temperature = 23.5
name = "Max Mustermann"
is_logged_in = True

print("Type of age:", type(age))
print("Type of temperature:", type(temperature))
print("Type of name:", type(name))
print("Type of is_logged_in:", type(is_logged_in))
# Out:
# Type of age: <class 'int'>
# Type of temperature: <class 'float'>
# Type of name: <class 'str'>
# Type of is_logged_in: <class 'bool'>

# %%
# 2. str() function

# Example: Converting other data types to strings
age_str = str(age)
temperature_str = str(temperature)
print("Age as string:", age_str)
print("Temperature as string:", temperature_str)
# Out:
# Age as string: 25
# Temperature as string: 23.5

# %%
# 3. int() function

# Example: Converting other data types to integers
temperature_int = int(temperature)
print("Temperature as integer:", temperature_int)
# Out:
# Temperature as integer: 23

# %%
# 4. float() function

# Example: Converting other data types to floats
age_float = float(age)
print("Age as float:", age_float)
# Out:
# Age as float: 25.0

# %%
# 5. len() function

# Example: Getting the length of a string
name_length = len(name)
print("Length of name:", name_length)
# Out:
# Length of name: 14

# %%
# 6. bool() function

# Example: Converting other data types to boolean
empty_string = ""
non_empty_string = "Hello"
print("Boolean value of empty string:", bool(empty_string))
print("Boolean value of non-empty string:", bool(non_empty_string))
# Out:
# Boolean value of empty string: False
# Boolean value of non-empty string: True

# %% [markdown]
# ### Abstract data types and data structures in Python

# %%
# 1. Complex numbers
complex_number = 1 + 2j  # Define a complex number
print("Complex Number:", complex_number)  # Print the complex number

# Addition of complex numbers
another_complex = 2 + 3j
sum_complex = complex_number + another_complex
print("Sum of Complex Numbers:", sum_complex)  # Output the sum
# Out:
# Complex Number: (1+2j)
# Sum of Complex Numbers: (3+5j)

# %%
# 2. Tuples
my_tuple = (1, 2, 3)  # Create a tuple
print("Tuple:", my_tuple)

# Accessing elements in a tuple
print("First element of the tuple:", my_tuple[0])  # Output the first element
# Out:
# Tuple: (1, 2, 3)
# First element of the tuple: 1

# %%
# 3. Lists
my_list = [1, 2, 3, 4, 5]  # Create a list
print("List before modification:", my_list)

# Modifying a list
my_list.append(6)  # Add an element to the list
print("List after adding an element:", my_list)
# Out:
# List before modification: [1, 2, 3, 4, 5]
# List after adding an element: [1, 2, 3, 4, 5, 6]

# %%
# 4. Dictionaries
my_dict = {"A": 1, "B": 2}  # Create a dictionary
print("Dictionary:", my_dict)

# Accessing a value by key
print("Value for key 'A':", my_dict["A"])  # Output the value for key 'A'
# Out:
# Dictionary: {'A': 1, 'B': 2}
# Value for key 'A': 1

# %%
# 5. Sets
my_set = {1, 2, 3, 3, 4}  # Create a set
print("Set:", my_set)  # Output the set (duplicates are removed)
# Out:
# Set: {1, 2, 3, 4}

# %%
# 6. Functions
def add_numbers(a, b):
    """Return the sum of two numbers."""
    return a + b  # Return the sum

# Using the function
result = add_numbers(5, 3)
print("Sum of 5 and 3:", result)  # Output the result
# Out:
# Sum of 5 and 3: 8

# %%
# 7. Classes
class Car:
    """A class representing a car."""
    
    def __init__(self, brand, model):
        """Initialize the car with brand and model."""
        self.brand = brand
        self.model = model

    def describe(self):
        """Return a description of the car."""
        return f"{self.brand} {self.model}"  # Return a string description

# Create an instance of the Car class
my_car = Car("Toyota", "Corolla")
print("Car description:", my_car.describe())  # Output the car description
# Out:
# Car description: Toyota Corolla

# %% [markdown]
# ### Structurized data and its properties in Python

# %%
# Import necessary libraries
import sqlite3
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# Read a csv file as pandas dataframe
df_people = pd.read_csv('../../data/day_2/people.csv', delimiter=",")
df_people.drop(columns=['Index'], inplace=True) # Remove duplikate index column
df_people
# Out:
#             User Id First Name  Last Name     Sex                       Email  \
# 0   88F7B33d2bcf9f5     Shelby    Terrell    Male        elijah57@example.net
# 1   f90cD3E76f1A9b9    Phillip    Summers  Female       bethany14@example.com
# 2   DbeAb8CcdfeFC2c   Kristine     Travis    Male       bthompson@example.com
# 3   A31Bee3c201ef58    Yesenia   Martinez    Male   kaitlinkaiser@example.com
# 4   1bA7A3dc874da3c       Lori       Todd    Male  buchananmanuel@example.net
# ..              ...        ...        ...     ...                         ...
# 95  5eFda7caAeB260E     Dennis     Barnes  Female         bmartin@example.org
# 96  CCbFce93d3720bE      Steve  Patterson  Female       latasha46@example.net
# 97  2fEc528aFAF0b69     Wesley       Bray    Male        regina11@example.org
# 98  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female  alexiscantrell@example.org
# 99  b8D0aD3490FC7e1     Mariah    Bernard    Male       pcopeland@example.org
#
#                      Phone Date of birth              Job Title
# 0   001-084-906-7849x73518    1945-10-26        Games developer
# 1        214.112.6044x4913    1910-03-24         Phytotherapist
# 2             277.609.7938    1992-07-02              Homeopath
# 3             584.094.6111    2017-08-03      Market researcher
# 4        689-207-3558x7233    1938-12-01     Veterinary surgeon
# ..                     ...           ...                    ...
# 95    001-095-524-2112x257    1954-07-30      Software engineer
# 96        001-865-478-5157    1932-04-29              Barrister
# 97      995-542-3004x76800    1994-12-28         Police officer
# 98    001-273-685-6932x092    2012-04-12   Broadcast journalist
# 99     (341)594-6554x44657    2016-11-15  IT sales professional
#
# [100 rows x 8 columns]

# %%
# Show tables of a database

# 1. Connect to the database
conn = sqlite3.connect('../../data/day_2/chinook.db')  # Connect to your database
cur = conn.cursor()  # Create a cursor object

# 2. Query to get all tables in the database
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# 3. Fetch and print all table names
tables = cur.fetchall()  # Fetch all results
print("Tables in the database:")
print("-"*23)
for table in tables:
    print(table[0])  # Print the name of each table

# 4. Close the connection
conn.close()
# Out:
# Tables in the database:
# -----------------------
# Album
# Artist
# Customer
# Employee
# Genre
# Invoice
# InvoiceLine
# MediaType
# Playlist
# PlaylistTrack
# Track

# %%
# Extract a database table as dataframe

# 1. Connect to the database
conn = sqlite3.connect('../../data/day_2/chinook.db')  # Connect to your database
cur = conn.cursor()  # Create a cursor object

# 2. Query the desired table as dataframe
df_chinook = pd.read_sql_query(f"SELECT * FROM Track;", conn)

# 3. Close the connection
conn.close()

df_chinook
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# 0               1        1          Angus Young, Malcolm Young, Brian Johnson
# 1               2        1  U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...
# 2               2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3               2        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4               2        1                         Deaffy & R.A. Smith-Diesel
# ...           ...      ...                                                ...
# 3498            2       24                                               None
# 3499            2       24                                     Franz Schubert
# 3500            2       24                                 Claudio Monteverdi
# 3501            2       24                            Wolfgang Amadeus Mozart
# 3502            2       10                                       Philip Glass
#
#       Milliseconds     Bytes  UnitPrice
# 0           343719  11170334       0.99
# 1           342562   5510424       0.99
# 2           230619   3990994       0.99
# 3           252051   4331779       0.99
# 4           375418   6290521       0.99
# ...            ...       ...        ...
# 3498        286741   4718950       0.99
# 3499        139200   2283131       0.99
# 3500         66639   1189062       0.99
# 3501        221331   3665114       0.99
# 3502        206005   3305164       0.99
#
# [3503 rows x 9 columns]

# %%
# Print information about the dataframes
print(df_people.info())
print("-"*48)
print(df_chinook.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User Id        100 non-null    object
#  1   First Name     100 non-null    object
#  2   Last Name      100 non-null    object
#  3   Sex            100 non-null    object
#  4   Email          100 non-null    object
#  5   Phone          100 non-null    object
#  6   Date of birth  100 non-null    object
#  7   Job Title      100 non-null    object
# dtypes: object(8)
# memory usage: 6.4+ KB
# None
# ------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3503 entries, 0 to 3502
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TrackId       3503 non-null   int64
#  1   Name          3503 non-null   object
#  2   AlbumId       3503 non-null   int64
#  3   MediaTypeId   3503 non-null   int64
#  4   GenreId       3503 non-null   int64
#  5   Composer      2526 non-null   object
#  6   Milliseconds  3503 non-null   int64
#  7   Bytes         3503 non-null   int64
#  8   UnitPrice     3503 non-null   float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 246.4+ KB
# None

# %%
# Describe properties of the dataframes
print(df_people.describe())
print("-"*80)
print(df_chinook.describe())
# Out:
#                 User Id First Name Last Name     Sex                 Email  \
# count               100        100       100     100                   100
# unique              100         94        95       2                   100
# top     88F7B33d2bcf9f5     Isaiah   Andrews  Female  elijah57@example.net
# freq                  1          2         3      53                     1
#
#                          Phone Date of birth             Job Title
# count                      100           100                   100
# unique                     100           100                    91
# top     001-084-906-7849x73518    1945-10-26  Biochemist, clinical
# freq                         1             1                     3
# --------------------------------------------------------------------------------
#            TrackId      AlbumId  MediaTypeId      GenreId  Milliseconds  \
# count  3503.000000  3503.000000  3503.000000  3503.000000  3.503000e+03
# mean   1752.000000   140.929489     1.208393     5.725378  3.935992e+05
# std    1011.373324    81.775395     0.580443     6.190204  5.350054e+05
# min       1.000000     1.000000     1.000000     1.000000  1.071000e+03
# 25%     876.500000    70.500000     1.000000     1.000000  2.072810e+05
# 50%    1752.000000   141.000000     1.000000     3.000000  2.556340e+05
# 75%    2627.500000   212.000000     1.000000     7.000000  3.216450e+05
# max    3503.000000   347.000000     5.000000    25.000000  5.286953e+06
#
#               Bytes    UnitPrice
# count  3.503000e+03  3503.000000
# mean   3.351021e+07     1.050805
# std    1.053925e+08     0.239006
# min    3.874700e+04     0.990000
# 25%    6.342566e+06     0.990000
# 50%    8.107896e+06     0.990000
# 75%    1.026679e+07     0.990000
# max    1.059546e+09     1.990000

# %%
# Select all rows where the genre is Classical
df_classical = df_chinook[df_chinook["GenreId"] == 24]
df_classical
# Out:
#       TrackId                                               Name  AlbumId  \
# 3358     3359  Symphony No. 3 in E-flat major, Op. 55, "Eroic...      268
# 3402     3403                             Intoitus: Adorate Deum      272
# 3403     3404                                 Miserere mei, Deus      273
# 3404     3405               Canon and Gigue in D Major: I. Canon      274
# 3405     3406  Concerto No. 1 in E Major, RV 269 "Spring": I....      275
# ...       ...                                                ...      ...
# 3497     3498  Concerto for Violin, Strings and Continuo in G...      342
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
#
#       MediaTypeId  GenreId                  Composer  Milliseconds     Bytes  \
# 3358            5       24      Ludwig van Beethoven        356426   5817216
# 3402            2       24                 Anonymous        245317   4123531
# 3403            2       24          Gregorio Allegri        501503   8285941
# 3404            2       24          Johann Pachelbel        271788   4438393
# 3405            2       24           Antonio Vivaldi        199086   3347810
# ...           ...      ...                       ...           ...       ...
# 3497            4       24  Pietro Antonio Locatelli        493573  16454937
# 3498            2       24                      None        286741   4718950
# 3499            2       24            Franz Schubert        139200   2283131
# 3500            2       24        Claudio Monteverdi         66639   1189062
# 3501            2       24   Wolfgang Amadeus Mozart        221331   3665114
#
#       UnitPrice
# 3358       0.99
# 3402       0.99
# 3403       0.99
# 3404       0.99
# 3405       0.99
# ...         ...
# 3497       0.99
# 3498       0.99
# 3499       0.99
# 3500       0.99
# 3501       0.99
#
# [74 rows x 9 columns]

# %%
# Derive an age column from the birthdate column, then extract all people under 18 years old

# Convert the date string column to datetime format
df_people['Date of birth'] = pd.to_datetime(df_people['Date of birth'])

# Get the current date as datetime object
current_date = datetime.now()

# Apply relativedelta to calculate age and store it in new 'Age' column
df_people['Age'] = df_people['Date of birth'].apply(
    lambda dob: relativedelta(current_date, dob).years
)

# Select all rows with people under 18 years old
df_minors = df_people[df_people['Age'] < 18]
df_minors
# Out:
#             User Id First Name   Last Name     Sex  \
# 3   A31Bee3c201ef58    Yesenia    Martinez    Male
# 5   bfDD7CDEF5D865B       Erin         Day    Male
# 8   baDcC4DeefD8dEB       Dave     Farrell    Male
# 10  BF0BbA03C29Bb3b     Sheila        Ross  Female
# 17  311D775990f066d      Frank     Meadows    Male
# 25  c9F2282C40BEC1E       Sean      Levine    Male
# 40  7D0AcBF6CCac3fd    Matthew       Stone  Female
# 41  CEFA7BBCef013AE       Kirk       Walsh  Female
# 61  Ed724605A403D91      Kelli      Garner    Male
# 65  cEf02C076afa07f      Larry      Harper    Male
# 70  6a53a8D41dDF6de       Ryan      Benton    Male
# 76  dade3452F0c32FD   Jonathon    Atkinson    Male
# 78  DAf111987098ae4     Regina     Stevens    Male
# 82  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 98  Adc7ad9B6e4A1Fe     Summer    Oconnell  Female
# 99  b8D0aD3490FC7e1     Mariah     Bernard    Male
#
#                          Email                  Phone Date of birth  \
# 3    kaitlinkaiser@example.com           584.094.6111    2017-08-03
# 5          tconner@example.org  001-171-649-9856x5553    2015-10-28
# 8          nmccann@example.net     603-428-2429x27392    2018-10-06
# 10      huangcathy@example.com           895.881.4746    2008-03-20
# 17         gbrewer@example.org      429.965.3902x4447    2008-09-16
# 25     sallymiller@example.net             4915828504    2010-10-09
# 40        evelyn31@example.org           952-381-6360    2017-08-23
# 41   stephenfuller@example.org  001-826-496-5529x8661    2009-04-08
# 61     jodyvincent@example.org      995.000.4213x0982    2010-01-17
# 65         maria32@example.org   +1-244-630-3792x4121    2021-05-05
# 70     lopezdebbie@example.org    +1-695-557-9948x485    2020-10-06
# 76      gailfrench@example.net       874-037-2032x932    2011-07-19
# 78          xpoole@example.net           891-359-2684    2011-11-28
# 82       erikaball@example.net    +1-832-500-6044x475    2010-02-08
# 98  alexiscantrell@example.org   001-273-685-6932x092    2012-04-12
# 99       pcopeland@example.org    (341)594-6554x44657    2016-11-15
#
#                                             Job Title  Age
# 3                                   Market researcher    8
# 5                            Waste management officer   10
# 8                                              Lawyer    7
# 10                      Advertising account executive   17
# 17                             Audiological scientist   17
# 25                       Conservation officer, nature   15
# 40  Scientist, clinical (histocompatibility and im...    8
# 41                              Accounting technician   16
# 61                                      Retail banker   16
# 65                           Scientist, water quality    4
# 70                            Physiological scientist    5
# 76                             Psychologist, forensic   14
# 78                               Public house manager   14
# 82                         Contracting civil engineer   15
# 98                               Broadcast journalist   13
# 99                              IT sales professional    9

# %% [markdown]
# ### Unstructurized data and its properties in Python

# %%
# Import necessary libraries
import cv2
from ipywidgets import interact
from matplotlib import pyplot as plt
from scipy.io import wavfile
import numpy as np
import os

# %%
# Read in some mnist data as numpy array
mnist_data = []
for number in range(0, 10):
    for image in range(0, 10):
        mnist_data.append(cv2.imread(f'../../data/day_2/mini_mnist/{number}/{number}_{image}.jpg', cv2.IMREAD_GRAYSCALE))

# %%
# Show mnist arrays
def show_mnist_array(index):
    array = mnist_data[index]
    for row in array:
        print(" ".join(f"{value:3}" for value in row))

interact(show_mnist_array, index=(0, len(mnist_data)-1))
# Out:
# interactive(children=(IntSlider(value=49, description='index', max=99), Output()), _dom_classes=('widget-inter…
# <function __main__.show_mnist_array(index)>

# %%
# Show mnist arrays as images
def show_mnist_array_as_image(index):
    array = mnist_data[index]
    plt.imshow(array, cmap='gray')
    plt.axis('off')
    plt.show()

interact(show_mnist_array_as_image, index=(0, len(mnist_data)-1))
# Out:
# interactive(children=(IntSlider(value=49, description='index', max=99), Output()), _dom_classes=('widget-inter…
# <function __main__.show_mnist_array_as_image(index)>

# %%
# Check the average pixel value for each image in the dataset
avg_pxl_vals = [image.mean() for image in mnist_data]

plt.figure(figsize=(10, 5))
plt.bar(range(len(avg_pxl_vals)), avg_pxl_vals, color='skyblue')
plt.xlabel('Bild Index')
plt.ylabel('Durchschnittlicher Pixelwert')
plt.title('Durchschnittlicher Pixelwert pro Bild')
plt.show()

# %%
# Check the average pixel value for each number in the dataset
avg_pxl_vals_of_nums = [sum(avg_pxl_vals[i:i+10]) / 10 for i in range(0, len(avg_pxl_vals), 10)]

plt.figure(figsize=(10, 5))
plt.bar(range(len(avg_pxl_vals_of_nums)), avg_pxl_vals_of_nums, color='skyblue')
plt.xlabel('Bild Index')
plt.ylabel('Durchschnittlicher Pixelwert')
plt.title('Durchschnittlicher Pixelwert pro Bild')
plt.show()

# %%
# Show audio mnist as image
data_path = "../../data/day_2/mini_audio_mnist/"
filenames = []
for i in range(1, 4):
    filenames.append(os.listdir(data_path + f"{i}"))
num_files = sum([len(filenames[i]) for i in range(len(filenames))])

def show_audio_mnist_as_image(index):
    speaker = index // 40
    file = index % 40

    samplerate, data = wavfile.read(f'../../data/day_2/mini_audio_mnist/{speaker+1}/{filenames[speaker][file]}')

    time = np.linspace(0, len(data) / samplerate, num=len(data))

    plt.figure(figsize=(12, 4))
    plt.plot(time, data)
    plt.axis('off')
    plt.show()
    
interact(show_audio_mnist_as_image, index=(0, num_files-2))
# Out:
# interactive(children=(IntSlider(value=59, description='index', max=119), Output()), _dom_classes=('widget-inte…
# <function __main__.show_audio_mnist_as_image(index)>
